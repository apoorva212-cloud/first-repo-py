# %%
list1 = [False,True,"2",3,4,5]
b = 1 in list1
print(b)
# Out:
# True

# %%
my_tuple = (1,2,3,4)
lst1 = list(my_tuple)
lst1[1]
# Out:
# 2

# %%
x = [0,1,2]
x.insert(0,1)
del x[1]
# Out:
# [1, 0, 1, 2]

# %%
l1 = [1,3]
#l1[0] = 4
l2 = l1
l1[0] = 4
l2
# Out:
# [4, 3]

# %%
#data = [2.02 , "cool" , 3.03 , 4,5]
print([2.02 , "cool" , 3.03 , 4,5][1:3:2])
# Out:
# ['cool']

# %%
x = [10, 20, 30, 40, 50]
x[-3:-1]
# Out:
# [30, 40]

# %%
nums = [1,2,3]
vals = nums
del vals[1:2]

# %%
vals
# Out:
# [1, 3]

# %%
nums
# Out:
# [1, 3]

# %%
dct = {}
dct['1'] = (1,2)
dct['2'] = (2,1)

for x in dct.keys():
    print(dct[x][1],end = '')
# Out:
# 21

# %%
print(list('hello'))
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
d = {}
d[1] = 1
d['1'] = 2
d[1] += 1

sum = 0 
for k in d:
    sum += d[k]
print(sum)
# Out:
# 4

# %%
nums = []
vals = nums
vals.append(1)

# %%
vals
# Out:
# [1]

# %%
nums
# Out:
# [1]

# %%
data = {'a' : 1 , 'b' : 2, 'c' : 3}
print(data['a','b'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 data = {'a' : 1 , 'b' : 2, 'c' : 3}
# ----> 2 print(data['a','b'])
#
# KeyError: ('a', 'b')

# %%
data = {'a' : 1 , 'b' : 2, 'c' : 3}
for n in data:
    print(data[n])
# Out:
# 1
# 2
# 3

# %%
data = {'a' : 1 , 'b' : 2, 'c' : 3}
for key,value in data.items():
    print(data[key])
# Out:
# 1
# 2
# 3

# %%
L  = [i for i in range(-1,-2)]
L
# Out:
# []

# %%
nums = [1,2,3]
data = ('Peter', ) * (len(nums) - nums[::-1][0])
print(data)
# Out:
# ()
